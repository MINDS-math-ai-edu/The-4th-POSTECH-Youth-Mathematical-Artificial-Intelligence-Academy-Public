# %% [markdown]
# <a href="https://colab.research.google.com/github/Potdooshami/The-4-5th-POSTECH-Youth-Mathematical-Artificial-Intelligence-Academy-Public/blob/main/readsoonng.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 개발환경 세팅

# %% [markdown]
# 수능 pdf 다운로드

# %%
url = 'https://github.com/Potdooshami/The-4-5th-POSTECH-Youth-Mathematical-Artificial-Intelligence-Academy-Public/raw/main/2025%ED%95%99%EB%85%84%EB%8F%84-%EB%8C%80%ED%95%99%EC%88%98%ED%95%99%EB%8A%A5%EB%A0%A5%EC%8B%9C%ED%97%98-%EC%88%98%ED%95%99-%EB%AC%B8%EC%A0%9C.pdf'
# !wget {url}
# Out:
# --2025-09-17 17:02:33--  https://github.com/Potdooshami/The-4-5th-POSTECH-Youth-Mathematical-Artificial-Intelligence-Academy-Public/raw/main/2025%ED%95%99%EB%85%84%EB%8F%84-%EB%8C%80%ED%95%99%EC%88%98%ED%95%99%EB%8A%A5%EB%A0%A5%EC%8B%9C%ED%97%98-%EC%88%98%ED%95%99-%EB%AC%B8%EC%A0%9C.pdf
# Resolving github.com (github.com)... 140.82.116.4
# Connecting to github.com (github.com)|140.82.116.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/Potdooshami/The-4-5th-POSTECH-Youth-Mathematical-Artificial-Intelligence-Academy-Public/main/2025%ED%95%99%EB%85%84%EB%8F%84-%EB%8C%80%ED%95%99%EC%88%98%ED%95%99%EB%8A%A5%EB%A0%A5%EC%8B%9C%ED%97%98-%EC%88%98%ED%95%99-%EB%AC%B8%EC%A0%9C.pdf [following]
# ...

# %%
# !pip install pdf2image
# !apt-get install poppler-utils
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# poppler-utils is already the newest version (22.02.0-2ubuntu0.10).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.

# %%
from pdf2image import convert_from_path
import matplotlib.pyplot as plt
file_path = '/content/2025학년도-대학수학능력시험-수학-문제.pdf'

# %%
from pdf2image import convert_from_path, convert_from_bytes
pdf_path = '/content/sample.pdf'
images = convert_from_path(pdf_path, dpi=100, first_page=1, last_page=20) # Convert pages 1 to 20 with reduced DPI

# %%
img = images[0]

# %%
i = i+1
images[0]
# Out:
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=1170x1655>
